# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Import Dataset
# !gdown 18h-WsozeS8-nnd6Kg86niuJyB0GQkKNU
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18h-WsozeS8-nnd6Kg86niuJyB0GQkKNU
# To: /content/insurance.csv
# 100% 30.8k/30.8k [00:00<00:00, 51.0MB/s]

# %%
df = pd.read_csv('insurance.csv')

# %%
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice
# 0                         0         25000
# 1                         0         29000
# 2                         1         23000
# 3                         2         28000
# 4                         1         23000
# ..                      ...           ...
# 981                       0         15000
# 982                       3         28000
# 983                       1         29000
# 984                       1         39000
# 985                       1         15000
#
# [986 rows x 11 columns]

# %% [markdown]
# ##Feature Engineering

# %%
#Create BMI index

df['BMI'] = round(df['Weight'] / (df['Height']/100)**2,2)

# %%
#Create Total Risk Index

df['TotalRisk'] = df['Diabetes'] + df['BloodPressureProblems'] + df['AnyTransplants'] + df['AnyChronicDiseases'] + df['KnownAllergies'] + df['HistoryOfCancerInFamily'] + df['NumberOfMajorSurgeries']

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice    BMI  TotalRisk
# 0                       0         25000  23.73          0
# 1                       0         29000  22.53          1
# 2                       1         23000  23.63          3
# 3                       2         28000  27.77          5
# 4                       1         23000  31.93          2

# %% [markdown]
# #Random Forest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# 1. Define your features (x_v2) and target (y)
# Ensure these column names match your actual dataframe exactly!
x_v2 = df[['Age', 'AnyTransplants', 'AnyChronicDiseases', 'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'BMI', 'BloodPressureProblems','Diabetes', 'KnownAllergies']]
y = df['PremiumPrice']

# 2. Split the data (The missing step)
x_train, x_test, y_train, y_test = train_test_split(x_v2, y, test_size=0.2, random_state=42)

# 3. Scale the data (Creating the variables your error mentioned)
scaler = StandardScaler()
x_train_scaled_v2 = scaler.fit_transform(x_train)
x_test_scaled_v2 = scaler.transform(x_test)

# --- Now the Random Forest will work ---

# Initialize and Train
rf_model = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)
rf_model.fit(x_train_scaled_v2, y_train)

# Predict and Evaluate
y_pred_rf = rf_model.predict(x_test_scaled_v2)
r2_rf = r2_score(y_test, y_pred_rf)

print(f"--- Random Forest Results ---")
print(f"R2 Score: {r2_rf:.4f}")

# Feature Importance
rf_importance = pd.DataFrame({'Feature': x_v2.columns, 'Importance': rf_model.feature_importances_})
print("\nFeature Importance (Random Forest):")
print(rf_importance.sort_values(by='Importance', ascending=False))

mae_rf = mean_absolute_error(y_test, y_pred_rf)
print(f"Random Forest MAE: ₹{mae_rf:.2f}")
# Out:
# --- Random Forest Results ---
# R2 Score: 0.8654
#
# Feature Importance (Random Forest):
#                    Feature  Importance
# 0                      Age    0.637714
# 5                      BMI    0.147683
# 1           AnyTransplants    0.096713
# 2       AnyChronicDiseases    0.039411
# 4   NumberOfMajorSurgeries    0.030881
# 3  HistoryOfCancerInFamily    0.022756
# 6    BloodPressureProblems    0.010380
# 7                 Diabetes    0.008545
# 8           KnownAllergies    0.005916
# Random Forest MAE: ₹1419.01

# %% [markdown]
# First, we need to mount your Google Drive to access it from Colab. You will be prompted to authorize Colab to access your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Now, let's define the correct path within your mounted Google Drive and save the files there. The path `G:\My Drive\Scaler\Scaler_PortfolioProject_Module` translates to `/content/drive/My Drive/Scaler/Scaler_PortfolioProject_Module` in Colab.

# %%
import os
import pickle

drive_path = '/content/drive/My Drive/Scaler/Scaler_PortfolioProject_Module'

# Create the folder if it doesn't exist
if not os.path.exists(drive_path):
    os.makedirs(drive_path)
    print(f"Directory '{drive_path}' created successfully.")
else:
    print(f"Directory '{drive_path}' already exists.")

# Save the model into that folder
with open(os.path.join(drive_path, 'insurance_rf_model.pkl'), 'wb') as f:
    pickle.dump(rf_model, f)

# Save the scaler into that folder
with open(os.path.join(drive_path, 'scaler.pkl'), 'wb') as f:
    pickle.dump(scaler, f)

print(f"Success! Files are now inside the '{drive_path}' folder.")
# Out:
# Directory '/content/drive/My Drive/Scaler/Scaler_PortfolioProject_Module' already exists.
# Success! Files are now inside the '/content/drive/My Drive/Scaler/Scaler_PortfolioProject_Module' folder.
